# %% [markdown]
# ref : arXiv:1512.03385v1 [cs.CV] 10 Dec 2015

# %%
#import required packages
import tensorflow as tf
from keras.layers import Layer
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils import plot_model
from resnets_utils import *
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
get_ipython().magic('matplotlib inline')

# %%
import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

# %%
# create the bottleneck for our resnet
def Bottleneck_Identity(X, f, filters, stage, block):
    '''
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    out -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    '''
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    #retrieve filters
    F1, F2, F3 = filters
    
    # save the input value for the shrotcut path and to add it later
    X_shortcut = X
    
    # first component of main path
    out = Conv2D(filters=F1, kernel_size=(1, 1),
              strides=(1, 1), padding='valid', name = conv_name_base + '2a',
              kernel_initializer= glorot_uniform(seed=0))(X)
    out = BatchNormalization(axis=-1, name = bn_name_base + '2a')(out)
    out = Activation('relu')(out)
    
    # second component of the main path
    out = Conv2D(filters=F2, kernel_size=(f, f),
                strides=(1, 1), padding='same', name = conv_name_base + '2b',
                kernel_initializer=glorot_uniform(seed=0))(out)
    out = BatchNormalization(axis=-1, name = bn_name_base + '2b')(out)
    out = Activation('relu')(out)
    
    # third component of the main path
    out = Conv2D(filters= F3, kernel_size=(1, 1),
                strides=(1, 1), padding='valid', name = conv_name_base + '2c',
                kernel_initializer=glorot_uniform(seed=0))(out)
    out = BatchNormalization(axis=-1, name = bn_name_base + '2c')(out)
    
    #upsample X_shortcut to get the same dimensions
    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1),
                       strides=(1, 1), padding='valid',
                       kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    
    # Now add shortcut to the main path
    out = Add()([out, X_shortcut])
    # Now pass it through relu activation
    out = Activation('relu')(out)
    
    return out

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
tf.reset_default_graph()
with tf.Session() as test:
    np.random.seed(1)
    A_prev = tf.placeholder('float', [1000, 64, 64, 6])
    X = np.random.randn(1000, 64, 64, 6)
    A = Bottleneck_Identity(A_prev, f=3, filters=[2, 4, 8], stage = 1, block='a')
    test.run(tf.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev:X, K.learning_phase(): 0})
    print('out = ' + str(out[0][0][0][0]))
# Out:
# out = [0.14369303 0.         1.7858351  0.         0.         0.39647472
#  0.         0.03609586]

# %%
def Bottleneck_convolutional(X, output_channels, stage, block):
    
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # save the input for shortcut path
    X_shortcut = X
    
    ### MAIN PATH ###
    # first block
    out = Conv2D(filters=output_channels, kernel_size=(1, 1),
              strides=(2, 2), padding='valid', name = conv_name_base + '2a',
              kernel_initializer=glorot_uniform(seed=0))(X)
    out = BatchNormalization(axis=-1, name = bn_name_base + '2a')(out)
    out = Activation('relu')(out)
    
    # Second block
    out = Conv2D(filters=output_channels, kernel_size=(3, 3),
                strides=(1, 1), padding='same', name = conv_name_base + '2b',
                kernel_initializer=glorot_uniform(seed = 0))(out)
    out = BatchNormalization(axis=-1, name = bn_name_base + '2b')(out)
    out = Activation('relu')(out)
    
    # Third block
    out = Conv2D(filters=output_channels * 4, kernel_size=(1, 1),
                strides=(1, 1), padding='valid', name = conv_name_base + '2c',
                kernel_initializer=glorot_uniform(seed=0))(out)
    out = BatchNormalization(axis=-1, name = bn_name_base + '2c')
    
    # Shortcut path
    X_shortcut = Conv2D(filters=output_channels * 4, kernel_size=(1,1),
                       strides=(2, 2), padding='valid', name = conv_name_base + '1',
                       kernel_initializer= glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=-1, name = bn_name_base + '1')(X_shortcut)
    
    # Now add the shortcut to the output of main path and then pass through relu activation
    out = Add()([X_shortcut, out])
    out = Activation('relu')(out)
    
    return out

# %%
from keras.models import Model

# %%
def Resnet50(input_shape=(64, 64, 3), classes = 6):
    """
    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    X_input = Input(input_shape) # input tensor
    
    #zero padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    #stage-1
    """
    (7, 7) * 64 => Maxpool(3, 3) : s = 2
    """
    X = Conv2D(filters=64, kernel_size=(7, 7),
                strides=2, name = 'conv1',
                kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = -1, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=2)(X)
    
    #stage-2
    X = Bottleneck_Identity(X, f=3, filters=[64, 64, 256], stage=2, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[64, 64, 256], stage=2, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[64, 64, 256], stage=2, block='C3')
    
    #stage-3
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C3')
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C4')
    
    #stage-4
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C3')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C4')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C5')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C6')
    
    #stage-5
    X = Bottleneck_Identity(X, f=3, filters=[512, 512, 2048], stage=5, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[512, 512, 2048], stage=5, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[512, 512, 2048], stage=5, block='C3')
    
    X = AveragePooling2D(pool_size=(2, 2), name = 'avg_pool')(X)
    
    #Output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name = 'fully_connected' +str(classes),
               kernel_initializer=glorot_uniform(seed=0))(X)
    
    #create Model
    model = Model(inputs=X_input, outputs=X, name = "ResNet50")
    
    return model

# %%
def Resnet101(input_shape=(64, 64, 3), classes = 6):
    """
    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    X_input = Input(input_shape) # input tensor
    
    #zero padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    #stage-1
    """
    (7, 7) * 64 => Maxpool(3, 3) : s = 2
    """
    X = Conv2D(filters=64, kernel_size=(7, 7),
                strides=2, name = 'conv1',
                kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = -1, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=2)(X)
    
    #stage-2
    X = Bottleneck_Identity(X, f=3, filters=[64, 64, 256], stage=2, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[64, 64, 256], stage=2, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[64, 64, 256], stage=2, block='C3')
    
    #stage-3
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C3')
    X = Bottleneck_Identity(X, f=3, filters=[128, 128, 512], stage=3, block='C4')
    
    #stage-4
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C3')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C4')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C5')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C6')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C7')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C8')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C9')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C10')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C11')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C12')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C13')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C14')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C15')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C16')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C17')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C18')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C19')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C20')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C21')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C22')
    X = Bottleneck_Identity(X, f=3, filters=[256, 256, 1024], stage=4, block='C23')
    
    #stage-5
    X = Bottleneck_Identity(X, f=3, filters=[512, 512, 2048], stage=5, block='C1')
    X = Bottleneck_Identity(X, f=3, filters=[512, 512, 2048], stage=5, block='C2')
    X = Bottleneck_Identity(X, f=3, filters=[512, 512, 2048], stage=5, block='C3')
    
    X = AveragePooling2D(pool_size=(2, 2), name = 'avg_pool')(X)
    
    #Output layer
    X = Flatten()(X)
    X = Dense(classes, activation='softmax', name = 'fully_connected' +str(classes),
               kernel_initializer=glorot_uniform(seed=0))(X)
    
    #create Model
    model = Model(inputs=X_input, outputs=X, name = "ResNet101")
    
    return model

# %%
# Assign the model
model = Resnet101(input_shape=(64, 64, 3), classes=6)
model.summary()
# Out:
# Model: "ResNet101"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 70, 70, 3)    0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 32, 32, 64)   9472        zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 32, 32, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 32, 32, 64)   0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 15, 15, 64)   0           activation_253[0][0]
# __________________________________________________________________________________________________
# res2C1_branch2a (Conv2D)        (None, 15, 15, 64)   4160        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bn2C1_branch2a (BatchNormalizat (None, 15, 15, 64)   256         res2C1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 15, 15, 64)   0           bn2C1_branch2a[0][0]
# __________________________________________________________________________________________________
# res2C1_branch2b (Conv2D)        (None, 15, 15, 64)   36928       activation_254[0][0]
# __________________________________________________________________________________________________
# bn2C1_branch2b (BatchNormalizat (None, 15, 15, 64)   256         res2C1_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 15, 15, 64)   0           bn2C1_branch2b[0][0]
# __________________________________________________________________________________________________
# res2C1_branch2c (Conv2D)        (None, 15, 15, 256)  16640       activation_255[0][0]
# __________________________________________________________________________________________________
# bn2C1_branch2c (BatchNormalizat (None, 15, 15, 256)  1024        res2C1_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 15, 15, 256)  16640       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 15, 15, 256)  0           bn2C1_branch2c[0][0]
#                                                                  conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 15, 15, 256)  0           add_84[0][0]
# __________________________________________________________________________________________________
# res2C2_branch2a (Conv2D)        (None, 15, 15, 64)   16448       activation_256[0][0]
# __________________________________________________________________________________________________
# bn2C2_branch2a (BatchNormalizat (None, 15, 15, 64)   256         res2C2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 15, 15, 64)   0           bn2C2_branch2a[0][0]
# __________________________________________________________________________________________________
# res2C2_branch2b (Conv2D)        (None, 15, 15, 64)   36928       activation_257[0][0]
# __________________________________________________________________________________________________
# bn2C2_branch2b (BatchNormalizat (None, 15, 15, 64)   256         res2C2_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 15, 15, 64)   0           bn2C2_branch2b[0][0]
# __________________________________________________________________________________________________
# res2C2_branch2c (Conv2D)        (None, 15, 15, 256)  16640       activation_258[0][0]
# __________________________________________________________________________________________________
# bn2C2_branch2c (BatchNormalizat (None, 15, 15, 256)  1024        res2C2_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 15, 15, 256)  65792       activation_256[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 15, 15, 256)  0           bn2C2_branch2c[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 15, 15, 256)  0           add_85[0][0]
# __________________________________________________________________________________________________
# res2C3_branch2a (Conv2D)        (None, 15, 15, 64)   16448       activation_259[0][0]
# __________________________________________________________________________________________________
# bn2C3_branch2a (BatchNormalizat (None, 15, 15, 64)   256         res2C3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 15, 15, 64)   0           bn2C3_branch2a[0][0]
# __________________________________________________________________________________________________
# res2C3_branch2b (Conv2D)        (None, 15, 15, 64)   36928       activation_260[0][0]
# __________________________________________________________________________________________________
# bn2C3_branch2b (BatchNormalizat (None, 15, 15, 64)   256         res2C3_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 15, 15, 64)   0           bn2C3_branch2b[0][0]
# __________________________________________________________________________________________________
# res2C3_branch2c (Conv2D)        (None, 15, 15, 256)  16640       activation_261[0][0]
# __________________________________________________________________________________________________
# bn2C3_branch2c (BatchNormalizat (None, 15, 15, 256)  1024        res2C3_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 15, 15, 256)  65792       activation_259[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 15, 15, 256)  0           bn2C3_branch2c[0][0]
#                                                                  conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 15, 15, 256)  0           add_86[0][0]
# __________________________________________________________________________________________________
# res3C1_branch2a (Conv2D)        (None, 15, 15, 128)  32896       activation_262[0][0]
# __________________________________________________________________________________________________
# bn3C1_branch2a (BatchNormalizat (None, 15, 15, 128)  512         res3C1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 15, 15, 128)  0           bn3C1_branch2a[0][0]
# __________________________________________________________________________________________________
# res3C1_branch2b (Conv2D)        (None, 15, 15, 128)  147584      activation_263[0][0]
# __________________________________________________________________________________________________
# bn3C1_branch2b (BatchNormalizat (None, 15, 15, 128)  512         res3C1_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 15, 15, 128)  0           bn3C1_branch2b[0][0]
# __________________________________________________________________________________________________
# res3C1_branch2c (Conv2D)        (None, 15, 15, 512)  66048       activation_264[0][0]
# __________________________________________________________________________________________________
# bn3C1_branch2c (BatchNormalizat (None, 15, 15, 512)  2048        res3C1_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 15, 15, 512)  131584      activation_262[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 15, 15, 512)  0           bn3C1_branch2c[0][0]
#                                                                  conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 15, 15, 512)  0           add_87[0][0]
# __________________________________________________________________________________________________
# res3C2_branch2a (Conv2D)        (None, 15, 15, 128)  65664       activation_265[0][0]
# __________________________________________________________________________________________________
# bn3C2_branch2a (BatchNormalizat (None, 15, 15, 128)  512         res3C2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 15, 15, 128)  0           bn3C2_branch2a[0][0]
# __________________________________________________________________________________________________
# res3C2_branch2b (Conv2D)        (None, 15, 15, 128)  147584      activation_266[0][0]
# __________________________________________________________________________________________________
# bn3C2_branch2b (BatchNormalizat (None, 15, 15, 128)  512         res3C2_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 15, 15, 128)  0           bn3C2_branch2b[0][0]
# __________________________________________________________________________________________________
# res3C2_branch2c (Conv2D)        (None, 15, 15, 512)  66048       activation_267[0][0]
# __________________________________________________________________________________________________
# bn3C2_branch2c (BatchNormalizat (None, 15, 15, 512)  2048        res3C2_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 15, 15, 512)  262656      activation_265[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 15, 15, 512)  0           bn3C2_branch2c[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 15, 15, 512)  0           add_88[0][0]
# __________________________________________________________________________________________________
# res3C3_branch2a (Conv2D)        (None, 15, 15, 128)  65664       activation_268[0][0]
# __________________________________________________________________________________________________
# bn3C3_branch2a (BatchNormalizat (None, 15, 15, 128)  512         res3C3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 15, 15, 128)  0           bn3C3_branch2a[0][0]
# __________________________________________________________________________________________________
# res3C3_branch2b (Conv2D)        (None, 15, 15, 128)  147584      activation_269[0][0]
# __________________________________________________________________________________________________
# bn3C3_branch2b (BatchNormalizat (None, 15, 15, 128)  512         res3C3_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 15, 15, 128)  0           bn3C3_branch2b[0][0]
# __________________________________________________________________________________________________
# res3C3_branch2c (Conv2D)        (None, 15, 15, 512)  66048       activation_270[0][0]
# __________________________________________________________________________________________________
# bn3C3_branch2c (BatchNormalizat (None, 15, 15, 512)  2048        res3C3_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 15, 15, 512)  262656      activation_268[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 15, 15, 512)  0           bn3C3_branch2c[0][0]
#                                                                  conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 15, 15, 512)  0           add_89[0][0]
# __________________________________________________________________________________________________
# res3C4_branch2a (Conv2D)        (None, 15, 15, 128)  65664       activation_271[0][0]
# __________________________________________________________________________________________________
# bn3C4_branch2a (BatchNormalizat (None, 15, 15, 128)  512         res3C4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 15, 15, 128)  0           bn3C4_branch2a[0][0]
# __________________________________________________________________________________________________
# res3C4_branch2b (Conv2D)        (None, 15, 15, 128)  147584      activation_272[0][0]
# __________________________________________________________________________________________________
# bn3C4_branch2b (BatchNormalizat (None, 15, 15, 128)  512         res3C4_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 15, 15, 128)  0           bn3C4_branch2b[0][0]
# __________________________________________________________________________________________________
# res3C4_branch2c (Conv2D)        (None, 15, 15, 512)  66048       activation_273[0][0]
# __________________________________________________________________________________________________
# bn3C4_branch2c (BatchNormalizat (None, 15, 15, 512)  2048        res3C4_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 15, 15, 512)  262656      activation_271[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 15, 15, 512)  0           bn3C4_branch2c[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 15, 15, 512)  0           add_90[0][0]
# __________________________________________________________________________________________________
# res4C1_branch2a (Conv2D)        (None, 15, 15, 256)  131328      activation_274[0][0]
# __________________________________________________________________________________________________
# bn4C1_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 15, 15, 256)  0           bn4C1_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C1_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_275[0][0]
# __________________________________________________________________________________________________
# bn4C1_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C1_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 15, 15, 256)  0           bn4C1_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C1_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_276[0][0]
# __________________________________________________________________________________________________
# bn4C1_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C1_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 15, 15, 1024) 525312      activation_274[0][0]
# __________________________________________________________________________________________________
# add_91 (Add)                    (None, 15, 15, 1024) 0           bn4C1_branch2c[0][0]
#                                                                  conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 15, 15, 1024) 0           add_91[0][0]
# __________________________________________________________________________________________________
# res4C2_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_277[0][0]
# __________________________________________________________________________________________________
# bn4C2_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 15, 15, 256)  0           bn4C2_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C2_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_278[0][0]
# __________________________________________________________________________________________________
# bn4C2_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C2_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 15, 15, 256)  0           bn4C2_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C2_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_279[0][0]
# __________________________________________________________________________________________________
# bn4C2_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C2_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_277[0][0]
# __________________________________________________________________________________________________
# add_92 (Add)                    (None, 15, 15, 1024) 0           bn4C2_branch2c[0][0]
#                                                                  conv2d_92[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 15, 15, 1024) 0           add_92[0][0]
# __________________________________________________________________________________________________
# res4C3_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_280[0][0]
# __________________________________________________________________________________________________
# bn4C3_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 15, 15, 256)  0           bn4C3_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C3_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_281[0][0]
# __________________________________________________________________________________________________
# bn4C3_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C3_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_282 (Activation)     (None, 15, 15, 256)  0           bn4C3_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C3_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_282[0][0]
# __________________________________________________________________________________________________
# bn4C3_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C3_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_280[0][0]
# __________________________________________________________________________________________________
# add_93 (Add)                    (None, 15, 15, 1024) 0           bn4C3_branch2c[0][0]
#                                                                  conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_283 (Activation)     (None, 15, 15, 1024) 0           add_93[0][0]
# __________________________________________________________________________________________________
# res4C4_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_283[0][0]
# __________________________________________________________________________________________________
# bn4C4_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C4_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_284 (Activation)     (None, 15, 15, 256)  0           bn4C4_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C4_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_284[0][0]
# __________________________________________________________________________________________________
# bn4C4_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C4_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_285 (Activation)     (None, 15, 15, 256)  0           bn4C4_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C4_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_285[0][0]
# __________________________________________________________________________________________________
# bn4C4_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C4_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_283[0][0]
# __________________________________________________________________________________________________
# add_94 (Add)                    (None, 15, 15, 1024) 0           bn4C4_branch2c[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_286 (Activation)     (None, 15, 15, 1024) 0           add_94[0][0]
# __________________________________________________________________________________________________
# res4C5_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_286[0][0]
# __________________________________________________________________________________________________
# bn4C5_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C5_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_287 (Activation)     (None, 15, 15, 256)  0           bn4C5_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C5_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_287[0][0]
# __________________________________________________________________________________________________
# bn4C5_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C5_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_288 (Activation)     (None, 15, 15, 256)  0           bn4C5_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C5_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_288[0][0]
# __________________________________________________________________________________________________
# bn4C5_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C5_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_286[0][0]
# __________________________________________________________________________________________________
# add_95 (Add)                    (None, 15, 15, 1024) 0           bn4C5_branch2c[0][0]
#                                                                  conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_289 (Activation)     (None, 15, 15, 1024) 0           add_95[0][0]
# __________________________________________________________________________________________________
# res4C6_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_289[0][0]
# __________________________________________________________________________________________________
# bn4C6_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C6_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_290 (Activation)     (None, 15, 15, 256)  0           bn4C6_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C6_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_290[0][0]
# __________________________________________________________________________________________________
# bn4C6_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C6_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_291 (Activation)     (None, 15, 15, 256)  0           bn4C6_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C6_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_291[0][0]
# __________________________________________________________________________________________________
# bn4C6_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C6_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_289[0][0]
# __________________________________________________________________________________________________
# add_96 (Add)                    (None, 15, 15, 1024) 0           bn4C6_branch2c[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_292 (Activation)     (None, 15, 15, 1024) 0           add_96[0][0]
# __________________________________________________________________________________________________
# res4C7_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_292[0][0]
# __________________________________________________________________________________________________
# bn4C7_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C7_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_293 (Activation)     (None, 15, 15, 256)  0           bn4C7_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C7_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_293[0][0]
# __________________________________________________________________________________________________
# bn4C7_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C7_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_294 (Activation)     (None, 15, 15, 256)  0           bn4C7_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C7_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_294[0][0]
# __________________________________________________________________________________________________
# bn4C7_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C7_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_292[0][0]
# __________________________________________________________________________________________________
# add_97 (Add)                    (None, 15, 15, 1024) 0           bn4C7_branch2c[0][0]
#                                                                  conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_295 (Activation)     (None, 15, 15, 1024) 0           add_97[0][0]
# __________________________________________________________________________________________________
# res4C8_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_295[0][0]
# __________________________________________________________________________________________________
# bn4C8_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C8_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_296 (Activation)     (None, 15, 15, 256)  0           bn4C8_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C8_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_296[0][0]
# __________________________________________________________________________________________________
# bn4C8_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C8_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_297 (Activation)     (None, 15, 15, 256)  0           bn4C8_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C8_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_297[0][0]
# __________________________________________________________________________________________________
# bn4C8_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C8_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_295[0][0]
# __________________________________________________________________________________________________
# add_98 (Add)                    (None, 15, 15, 1024) 0           bn4C8_branch2c[0][0]
#                                                                  conv2d_98[0][0]
# __________________________________________________________________________________________________
# activation_298 (Activation)     (None, 15, 15, 1024) 0           add_98[0][0]
# __________________________________________________________________________________________________
# res4C9_branch2a (Conv2D)        (None, 15, 15, 256)  262400      activation_298[0][0]
# __________________________________________________________________________________________________
# bn4C9_branch2a (BatchNormalizat (None, 15, 15, 256)  1024        res4C9_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_299 (Activation)     (None, 15, 15, 256)  0           bn4C9_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C9_branch2b (Conv2D)        (None, 15, 15, 256)  590080      activation_299[0][0]
# __________________________________________________________________________________________________
# bn4C9_branch2b (BatchNormalizat (None, 15, 15, 256)  1024        res4C9_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_300 (Activation)     (None, 15, 15, 256)  0           bn4C9_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C9_branch2c (Conv2D)        (None, 15, 15, 1024) 263168      activation_300[0][0]
# __________________________________________________________________________________________________
# bn4C9_branch2c (BatchNormalizat (None, 15, 15, 1024) 4096        res4C9_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 15, 15, 1024) 1049600     activation_298[0][0]
# __________________________________________________________________________________________________
# add_99 (Add)                    (None, 15, 15, 1024) 0           bn4C9_branch2c[0][0]
#                                                                  conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_301 (Activation)     (None, 15, 15, 1024) 0           add_99[0][0]
# __________________________________________________________________________________________________
# res4C10_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_301[0][0]
# __________________________________________________________________________________________________
# bn4C10_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C10_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_302 (Activation)     (None, 15, 15, 256)  0           bn4C10_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C10_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_302[0][0]
# __________________________________________________________________________________________________
# bn4C10_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C10_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_303 (Activation)     (None, 15, 15, 256)  0           bn4C10_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C10_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_303[0][0]
# __________________________________________________________________________________________________
# bn4C10_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C10_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_301[0][0]
# __________________________________________________________________________________________________
# add_100 (Add)                   (None, 15, 15, 1024) 0           bn4C10_branch2c[0][0]
#                                                                  conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_304 (Activation)     (None, 15, 15, 1024) 0           add_100[0][0]
# __________________________________________________________________________________________________
# res4C11_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_304[0][0]
# __________________________________________________________________________________________________
# bn4C11_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C11_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_305 (Activation)     (None, 15, 15, 256)  0           bn4C11_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C11_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_305[0][0]
# __________________________________________________________________________________________________
# bn4C11_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C11_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_306 (Activation)     (None, 15, 15, 256)  0           bn4C11_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C11_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_306[0][0]
# __________________________________________________________________________________________________
# bn4C11_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C11_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_304[0][0]
# __________________________________________________________________________________________________
# add_101 (Add)                   (None, 15, 15, 1024) 0           bn4C11_branch2c[0][0]
#                                                                  conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_307 (Activation)     (None, 15, 15, 1024) 0           add_101[0][0]
# __________________________________________________________________________________________________
# res4C12_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_307[0][0]
# __________________________________________________________________________________________________
# bn4C12_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C12_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_308 (Activation)     (None, 15, 15, 256)  0           bn4C12_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C12_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_308[0][0]
# __________________________________________________________________________________________________
# bn4C12_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C12_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_309 (Activation)     (None, 15, 15, 256)  0           bn4C12_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C12_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_309[0][0]
# __________________________________________________________________________________________________
# bn4C12_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C12_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_307[0][0]
# __________________________________________________________________________________________________
# add_102 (Add)                   (None, 15, 15, 1024) 0           bn4C12_branch2c[0][0]
#                                                                  conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_310 (Activation)     (None, 15, 15, 1024) 0           add_102[0][0]
# __________________________________________________________________________________________________
# res4C13_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_310[0][0]
# __________________________________________________________________________________________________
# bn4C13_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C13_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_311 (Activation)     (None, 15, 15, 256)  0           bn4C13_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C13_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_311[0][0]
# __________________________________________________________________________________________________
# bn4C13_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C13_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_312 (Activation)     (None, 15, 15, 256)  0           bn4C13_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C13_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_312[0][0]
# __________________________________________________________________________________________________
# bn4C13_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C13_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_310[0][0]
# __________________________________________________________________________________________________
# add_103 (Add)                   (None, 15, 15, 1024) 0           bn4C13_branch2c[0][0]
#                                                                  conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_313 (Activation)     (None, 15, 15, 1024) 0           add_103[0][0]
# __________________________________________________________________________________________________
# res4C14_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_313[0][0]
# __________________________________________________________________________________________________
# bn4C14_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C14_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_314 (Activation)     (None, 15, 15, 256)  0           bn4C14_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C14_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_314[0][0]
# __________________________________________________________________________________________________
# bn4C14_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C14_branch2b[0][0]
# ...
# bn4C20_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C20_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_333 (Activation)     (None, 15, 15, 256)  0           bn4C20_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C20_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_333[0][0]
# __________________________________________________________________________________________________
# bn4C20_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C20_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_331[0][0]
# __________________________________________________________________________________________________
# add_110 (Add)                   (None, 15, 15, 1024) 0           bn4C20_branch2c[0][0]
#                                                                  conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_334 (Activation)     (None, 15, 15, 1024) 0           add_110[0][0]
# __________________________________________________________________________________________________
# res4C21_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_334[0][0]
# __________________________________________________________________________________________________
# bn4C21_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C21_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_335 (Activation)     (None, 15, 15, 256)  0           bn4C21_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C21_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_335[0][0]
# __________________________________________________________________________________________________
# bn4C21_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C21_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_336 (Activation)     (None, 15, 15, 256)  0           bn4C21_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C21_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_336[0][0]
# __________________________________________________________________________________________________
# bn4C21_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C21_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_334[0][0]
# __________________________________________________________________________________________________
# add_111 (Add)                   (None, 15, 15, 1024) 0           bn4C21_branch2c[0][0]
#                                                                  conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_337 (Activation)     (None, 15, 15, 1024) 0           add_111[0][0]
# __________________________________________________________________________________________________
# res4C22_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_337[0][0]
# __________________________________________________________________________________________________
# bn4C22_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C22_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_338 (Activation)     (None, 15, 15, 256)  0           bn4C22_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C22_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_338[0][0]
# __________________________________________________________________________________________________
# bn4C22_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C22_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_339 (Activation)     (None, 15, 15, 256)  0           bn4C22_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C22_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_339[0][0]
# __________________________________________________________________________________________________
# bn4C22_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C22_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_337[0][0]
# __________________________________________________________________________________________________
# add_112 (Add)                   (None, 15, 15, 1024) 0           bn4C22_branch2c[0][0]
#                                                                  conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_340 (Activation)     (None, 15, 15, 1024) 0           add_112[0][0]
# __________________________________________________________________________________________________
# res4C23_branch2a (Conv2D)       (None, 15, 15, 256)  262400      activation_340[0][0]
# __________________________________________________________________________________________________
# bn4C23_branch2a (BatchNormaliza (None, 15, 15, 256)  1024        res4C23_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_341 (Activation)     (None, 15, 15, 256)  0           bn4C23_branch2a[0][0]
# __________________________________________________________________________________________________
# res4C23_branch2b (Conv2D)       (None, 15, 15, 256)  590080      activation_341[0][0]
# __________________________________________________________________________________________________
# bn4C23_branch2b (BatchNormaliza (None, 15, 15, 256)  1024        res4C23_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_342 (Activation)     (None, 15, 15, 256)  0           bn4C23_branch2b[0][0]
# __________________________________________________________________________________________________
# res4C23_branch2c (Conv2D)       (None, 15, 15, 1024) 263168      activation_342[0][0]
# __________________________________________________________________________________________________
# bn4C23_branch2c (BatchNormaliza (None, 15, 15, 1024) 4096        res4C23_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 15, 15, 1024) 1049600     activation_340[0][0]
# __________________________________________________________________________________________________
# add_113 (Add)                   (None, 15, 15, 1024) 0           bn4C23_branch2c[0][0]
#                                                                  conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_343 (Activation)     (None, 15, 15, 1024) 0           add_113[0][0]
# __________________________________________________________________________________________________
# res5C1_branch2a (Conv2D)        (None, 15, 15, 512)  524800      activation_343[0][0]
# __________________________________________________________________________________________________
# bn5C1_branch2a (BatchNormalizat (None, 15, 15, 512)  2048        res5C1_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_344 (Activation)     (None, 15, 15, 512)  0           bn5C1_branch2a[0][0]
# __________________________________________________________________________________________________
# res5C1_branch2b (Conv2D)        (None, 15, 15, 512)  2359808     activation_344[0][0]
# __________________________________________________________________________________________________
# bn5C1_branch2b (BatchNormalizat (None, 15, 15, 512)  2048        res5C1_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_345 (Activation)     (None, 15, 15, 512)  0           bn5C1_branch2b[0][0]
# __________________________________________________________________________________________________
# res5C1_branch2c (Conv2D)        (None, 15, 15, 2048) 1050624     activation_345[0][0]
# __________________________________________________________________________________________________
# bn5C1_branch2c (BatchNormalizat (None, 15, 15, 2048) 8192        res5C1_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 15, 15, 2048) 2099200     activation_343[0][0]
# __________________________________________________________________________________________________
# add_114 (Add)                   (None, 15, 15, 2048) 0           bn5C1_branch2c[0][0]
#                                                                  conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_346 (Activation)     (None, 15, 15, 2048) 0           add_114[0][0]
# __________________________________________________________________________________________________
# res5C2_branch2a (Conv2D)        (None, 15, 15, 512)  1049088     activation_346[0][0]
# __________________________________________________________________________________________________
# bn5C2_branch2a (BatchNormalizat (None, 15, 15, 512)  2048        res5C2_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_347 (Activation)     (None, 15, 15, 512)  0           bn5C2_branch2a[0][0]
# __________________________________________________________________________________________________
# res5C2_branch2b (Conv2D)        (None, 15, 15, 512)  2359808     activation_347[0][0]
# __________________________________________________________________________________________________
# bn5C2_branch2b (BatchNormalizat (None, 15, 15, 512)  2048        res5C2_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_348 (Activation)     (None, 15, 15, 512)  0           bn5C2_branch2b[0][0]
# __________________________________________________________________________________________________
# res5C2_branch2c (Conv2D)        (None, 15, 15, 2048) 1050624     activation_348[0][0]
# __________________________________________________________________________________________________
# bn5C2_branch2c (BatchNormalizat (None, 15, 15, 2048) 8192        res5C2_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 15, 15, 2048) 4196352     activation_346[0][0]
# __________________________________________________________________________________________________
# add_115 (Add)                   (None, 15, 15, 2048) 0           bn5C2_branch2c[0][0]
#                                                                  conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_349 (Activation)     (None, 15, 15, 2048) 0           add_115[0][0]
# __________________________________________________________________________________________________
# res5C3_branch2a (Conv2D)        (None, 15, 15, 512)  1049088     activation_349[0][0]
# __________________________________________________________________________________________________
# bn5C3_branch2a (BatchNormalizat (None, 15, 15, 512)  2048        res5C3_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_350 (Activation)     (None, 15, 15, 512)  0           bn5C3_branch2a[0][0]
# __________________________________________________________________________________________________
# res5C3_branch2b (Conv2D)        (None, 15, 15, 512)  2359808     activation_350[0][0]
# __________________________________________________________________________________________________
# bn5C3_branch2b (BatchNormalizat (None, 15, 15, 512)  2048        res5C3_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_351 (Activation)     (None, 15, 15, 512)  0           bn5C3_branch2b[0][0]
# __________________________________________________________________________________________________
# res5C3_branch2c (Conv2D)        (None, 15, 15, 2048) 1050624     activation_351[0][0]
# __________________________________________________________________________________________________
# bn5C3_branch2c (BatchNormalizat (None, 15, 15, 2048) 8192        res5C3_branch2c[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 15, 15, 2048) 4196352     activation_349[0][0]
# __________________________________________________________________________________________________
# add_116 (Add)                   (None, 15, 15, 2048) 0           bn5C3_branch2c[0][0]
#                                                                  conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_352 (Activation)     (None, 15, 15, 2048) 0           add_116[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 7, 7, 2048)   0           activation_352[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 100352)       0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fully_connected6 (Dense)        (None, 6)            602118      flatten_4[0][0]
# ==================================================================================================
# Total params: 75,648,390
# Trainable params: 75,550,726
# Non-trainable params: 97,664
# __________________________________________________________________________________________________

# %%
# compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#load our numeric signs dataset
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# %%
# Normalize image vectors into (o, 1) range
X_train = X_train_orig/ 255.0
X_test = X_test_orig/ 255.0

# %%
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

# %%
print("X_train shape", str(X_train.shape))
print("Y_train shape", str(Y_train.shape))
print("X_test shape", str(X_test.shape))
print("Y_test shape", str(Y_test.shape))
# Out:
# X_train shape (1080, 64, 64, 3)
# Y_train shape (1080, 6)
# X_test shape (120, 64, 64, 3)
# Y_test shape (120, 6)

# %%
model.fit(X_train, Y_train, epochs=2, batch_size=16)

# %%
preds = model.evaluate(X_test, Y_test)
# Out:
# 120/120 [==============================] - ETA:  - ETA:  - ETA:  - 4s 33ms/step

# %%
print(str(preds[0]))
print(str(preds[1]))
print(str(preds))
# Out:
# 1.7917092561721801
# 0.1666666716337204
# [1.7917092561721801, 0.1666666716337204]

# %%
model.save_weights("ResNet.h5")
